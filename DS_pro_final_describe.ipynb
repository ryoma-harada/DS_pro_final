# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/DSproFinaldata.csv')
df
# Out:
#     day     hpa  rainfall  temp_av  temp_max  temp_min  humidity_av  \
# 0    17  1007.5       0.0     11.2      17.2       5.9           36
# 1    18  1020.5       0.0      7.0      11.5       3.8           36
# 2    19  1020.2       0.0      7.0      10.6       3.4           53
# 3    20  1008.7       0.0      8.5      13.5       4.6           59
# 4    21  1008.3       0.0      7.7      13.1       3.3           41
# 5    22  1015.0       0.0      5.3      10.1       1.5           38
# 6    23  1023.8       0.0      5.0      10.6       0.1           47
# 7    24  1023.9       0.0      4.9       8.8       2.0           55
# 8    25  1018.2       0.0      6.3      12.1       1.0           56
# 9    26  1019.2       0.0      7.6      13.2       2.6           58
# 10   27  1022.5       0.0      8.4      12.6       4.3           50
# 11   28  1022.6       0.0      7.0      10.8       4.4           56
# 12   29  1018.2       0.0      7.8      13.8       2.2           61
# ...

# %%
df.describe()
# Out:
#              day          hpa   rainfall    temp_av   temp_max   temp_min  \
# count  15.000000    15.000000  15.000000  15.000000  15.000000  15.000000
# mean   24.000000  1016.660000   0.100000   7.460000  12.333333   3.286667
# std     4.472136     6.501956   0.387298   1.707044   2.063169   1.701624
# min    17.000000  1004.000000   0.000000   4.900000   8.800000   0.100000
# 25%    20.500000  1011.850000   0.000000   6.650000  10.700000   2.100000
# 50%    24.000000  1018.200000   0.000000   7.600000  12.600000   3.400000
# 75%    27.500000  1021.500000   0.000000   8.450000  13.350000   4.400000
# max    31.000000  1023.900000   1.500000  11.200000  17.200000   5.900000
#
#        humidity_av  humidity_min    suntime      day.1  screentime
# count    15.000000     15.000000  15.000000  15.000000   15.000000
# mean     52.533333     34.266667   6.753333  24.000000  673.000000
# std      11.685563     10.905219   2.199957   4.472136  198.395708
# ...

# %%
df = df.drop(columns = ["day.1"])

# %%
df
# Out:
#     day     hpa  rainfall  temp_av  temp_max  temp_min  humidity_av  \
# 0    17  1007.5       0.0     11.2      17.2       5.9           36
# 1    18  1020.5       0.0      7.0      11.5       3.8           36
# 2    19  1020.2       0.0      7.0      10.6       3.4           53
# 3    20  1008.7       0.0      8.5      13.5       4.6           59
# 4    21  1008.3       0.0      7.7      13.1       3.3           41
# 5    22  1015.0       0.0      5.3      10.1       1.5           38
# 6    23  1023.8       0.0      5.0      10.6       0.1           47
# 7    24  1023.9       0.0      4.9       8.8       2.0           55
# 8    25  1018.2       0.0      6.3      12.1       1.0           56
# 9    26  1019.2       0.0      7.6      13.2       2.6           58
# 10   27  1022.5       0.0      8.4      12.6       4.3           50
# 11   28  1022.6       0.0      7.0      10.8       4.4           56
# 12   29  1018.2       0.0      7.8      13.8       2.2           61
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##利用時間

# %%
plt.plot(df['day'], df['screentime'])
plt.xlabel('day')
plt.ylabel('screentime')
plt.xticks(range(17, 32, 1))
plt.show()

# %% [markdown]
# ##気圧

# %%
plt.plot(df['day'], df['hpa'])
plt.xlabel('day')
plt.ylabel('hpa')
plt.xticks(range(17, 32, 1))
plt.show()

# %% [markdown]
# ##気温

# %%
plt.plot(df['day'], df['temp_av'])
plt.plot(df['day'], df['temp_max'])
plt.plot(df['day'], df['temp_min'])
plt.xlabel('day')
plt.ylabel('temp')
plt.xticks(range(17, 32, 1))
plt.show()

# %% [markdown]
# ##湿度

# %%
plt.plot(df['day'], df['humidity_av'])
plt.plot(df['day'], df['humidity_min'])
plt.xlabel('day')
plt.ylabel('humidity')
plt.xticks(range(17, 32, 1))
plt.show()

# %% [markdown]
# ##日照時間

# %%
plt.plot(df['day'], df['suntime'])
plt.xlabel('day')
plt.ylabel('suntime')
plt.xticks(range(17, 32, 1))
plt.show()

# %% [markdown]
# ##結果と考察
